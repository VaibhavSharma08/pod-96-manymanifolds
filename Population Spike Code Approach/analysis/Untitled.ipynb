# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.imshow()

# %%
import seaborn as sns

# %%
sns.clustermap(np.load(f'../results/similarity_blocks/0block0.npy'))
# Out:
# D:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\matrix.py:624: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
from sklearn.manifold import MDS

# %%
embedding = MDS(n_components=2,dissimilarity='precomputed')

# %%
y = embedding.fit_transform(np.load(f'../results/similarity_blocks/0block0.npy'))

# %%
plt.plot(y[:,0],y[:,1],'.')
